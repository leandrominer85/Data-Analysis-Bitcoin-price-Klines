# %%
import pandas as pd
import glob
import os

# %%
def data_table(path = '..\data\cleaned'):
    
    
    '''
    This function receives a path for the data. First it asks the user wich file(complete path) he wants.
    Uses this to load the dataframe. Then ask the dates for slicing the data.
    Then it returns two dataframe with the column close_diff formated with a stylized function that shows
    the relative difference inside the column with a color gradient.
    The first dataframe is for the whole data. The second is filtered for the fundingRate column where it
    is different from zero.
    
    Input:
    path - str; the path to the original data 
    
    
    Output:
    full_df - Dataframe for the whole data (as sliced by the user)
    funding_df - - Dataframe with data only with funding rate (as sliced by the user)
    
    '''
    
    
    
    
    
    #Uses glob to get the list of files
    path = path
    files = glob.glob(path + "/*.csv")
    
    print("Select one of the data:")
    for i in files:
        print(i)
        
    #fet the file path
    file_path = input("File path")
    
    df = pd.read_csv(file_path, index_col="date")
    print()
    print("Select a date between {} and {}".format(df.index.min(), df.index.max()))
    print()
    
    
    #get the dates
    init_date = input("Begin date (format : year-month-day hour:min:sec). Ex: '2020-02-19 17:30:00'")
    final_date = input("Final date (format : year-month-day hour:min:sec). Ex: '2020-02-19 17:30:00'")
    
    global full_df
    global funding_df
    
    #drop the unused column and filter the data
    df.drop("Unnamed: 0",axis=1, inplace=True)
    df2 = df[init_date:final_date]
    df3 = df2[df2["fundingRate"] != 0]
    
    
    full_df = df2.style.bar(subset=['close_diff'], align='mid', color=['#d65f5f', '#5fba7d'])
    
    funding_df = df3.style.bar(subset=['close_diff'], align='mid', color=['#d65f5f', '#5fba7d'])
    

    return (full_df , funding_df)

# %%
data_table()
# Out:
# Select one of the data:
# ..\data\cleaned\ADAUSDT.csv
# ..\data\cleaned\DOTUSDT.csv
# ..\data\cleaned\EOSUSDT.csv
# ..\data\cleaned\ETHUSDT.csv
# ..\data\cleaned\LINKUSDT.csv
# ..\data\cleaned\LTCUSDT.csv
# ..\data\cleaned\SXPUSDT.csv
# ..\data\cleaned\VETUSDT.csv
# ..\data\cleaned\XRPUSDT.csv
# File path..\data\cleaned\ADAUSDT.csv
#
# Select a date between 2020-02-19 17:30:00 and 2021-02-19 12:00:00
#
# Begin date (format : year-month-day hour:min:sec). Ex: '2020-02-19 17:30:00'2020-02-19 17:30:00
# Final date (format : year-month-day hour:min:sec). Ex: '2020-02-19 17:30:00'2020-02-20 17:30:00
# (<pandas.io.formats.style.Styler at 0x1fcb0fdfc70>,
#  <pandas.io.formats.style.Styler at 0x1fcb0fbaa00>)

# %%
full_df
# Out:
# <style  type="text/css" >
# #T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow0_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow115_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow1156_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.6%, #5fba7d 47.6%, #5fba7d 58.5%, transparent 58.5%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 28.0%, #d65f5f 28.0%, #d65f5f 47.6%, transparent 47.6%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.6%, #5fba7d 47.6%, #5fba7d 58.0%, transparent 58.0%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow3_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow5_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow8_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow23_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow73_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow77_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow108_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow121_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow123_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow124_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow127_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow168_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow182_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow183_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow189_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow197_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow227_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow254_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow291_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow314_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow426_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow454_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow493_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow505_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow510_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow812_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow844_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow850_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow870_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.6%, #5fba7d 47.6%, #5fba7d 48.1%, transparent 48.1%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow4_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow93_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow99_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow101_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow158_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow159_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.6%, #5fba7d 47.6%, #5fba7d 50.3%, transparent 50.3%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow6_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow611_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.5%, #d65f5f 40.5%, #d65f5f 47.6%, transparent 47.6%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow7_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow22_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow33_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow37_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow104_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow106_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.3%, #d65f5f 44.3%, #d65f5f 47.6%, transparent 47.6%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow9_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow36_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow148_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow149_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow172_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow176_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.9%, #d65f5f 45.9%, #d65f5f 47.6%, transparent 47.6%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow10_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow117_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow370_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow406_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.6%, #5fba7d 47.6%, #5fba7d 55.2%, transparent 55.2%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow11_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow12_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow18_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow90_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow116_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow128_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow129_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow137_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow147_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow154_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.6%, #d65f5f 42.6%, #d65f5f 47.6%, transparent 47.6%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow13_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow278_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow385_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow522_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow700_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow778_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow787_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow807_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow879_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow902_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.6%, #5fba7d 47.6%, #5fba7d 54.1%, transparent 54.1%);
#         }#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow14_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow46_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow51_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow57_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow58_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow67_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow69_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow75_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow86_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow88_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow92_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow95_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow141_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow165_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow171_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow185_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow206_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow214_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow223_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow265_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow287_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow321_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow329_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow336_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow407_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow429_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow451_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow472_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow482_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow483_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow486_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow490_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow506_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow528_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow533_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow541_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow563_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow576_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow579_col4,#T_9bbd2846_7e85_11eb_aef7_9cb6d016a67erow588_col4,#T_9bbd2846_7e85_11eb_

# %%
funding_df
# Out:
# <style  type="text/css" >
# #T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 96.9%, transparent 96.9%);
#         }#T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 96.9%, #5fba7d 96.9%, #5fba7d 100.0%, transparent 100.0%);
#         }#T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.3%, #d65f5f 40.3%, #d65f5f 96.9%, transparent 96.9%);
#         }</style><table id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >open</th>        <th class="col_heading level0 col1" >high</th>        <th class="col_heading level0 col2" >low</th>        <th class="col_heading level0 col3" >close</th>        <th class="col_heading level0 col4" >close_diff</th>        <th class="col_heading level0 col5" >fundingRate</th>    </tr>    <tr>        <th class="index_name level0" >date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67elevel0_row0" class="row_heading level0 row0" >2020-02-20 00:00:00</th>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow0_col0" class="data row0 col0" >0.057310</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow0_col1" class="data row0 col1" >0.057310</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow0_col2" class="data row0 col2" >0.057000</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow0_col3" class="data row0 col3" >0.057000</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow0_col4" class="data row0 col4" >-0.005409</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow0_col5" class="data row0 col5" >0.000100</td>
#             </tr>
#             <tr>
#                         <th id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67elevel0_row1" class="row_heading level0 row1" >2020-02-20 08:00:00</th>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow1_col0" class="data row1 col0" >0.057830</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow1_col1" class="data row1 col1" >0.057840</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow1_col2" class="data row1 col2" >0.057790</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow1_col3" class="data row1 col3" >0.057840</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow1_col4" class="data row1 col4" >0.000173</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow1_col5" class="data row1 col5" >0.000100</td>
#             </tr>
#             <tr>
#                         <th id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67elevel0_row2" class="row_heading level0 row2" >2020-02-20 16:00:00</th>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow2_col0" class="data row2 col0" >0.056940</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow2_col1" class="data row2 col1" >0.056980</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow2_col2" class="data row2 col2" >0.056750</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow2_col3" class="data row2 col3" >0.056760</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow2_col4" class="data row2 col4" >-0.003161</td>
#                         <td id="T_ae510ccd_7e85_11eb_a29a_9cb6d016a67erow2_col5" class="data row2 col5" >0.000100</td>
#             </tr>
#     </tbody></table>
